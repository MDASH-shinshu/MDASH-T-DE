# %% [markdown]
# # データ表現
#
# 《学修項目》
# *   ◎コンピュータで扱うデータ（数値、文章、画像、音声、動画など）
# *   構造化データ、⾮構造化データ
# *   情報量の単位（ビット、バイト）、⼆進数、⽂字コード
# *   配列、⽊構造（ツリー）、グラフ
# *   画像の符号化、画素（ピクセル）、⾊の3要素（RGB）
# *   ⾳声の符号化、周波数、標本化、量⼦化
#
# 《キーワード》
# > データの種類，数と文字列，ビットとバイト，数の表現方法，テキストデータ，画像データ，音声データ，動画データ，構造化されたデータ，非構造化データ，配列とデータ，線形探索，木構造，二分探索，画像分析，音声データ分析

# %% [markdown]
# 《参考文献，参考書籍》
# *   [1] [東京大学MIセンター公開教材 「2-2 データ表現」](http://www.mi.u-tokyo.ac.jp/pdf/2-2_data_expression.pdf) [《利用条件CC BY-NC-SA》](https://creativecommons.org/licenses/by-nc-sa/4.0/deed.ja)
# *   [2] [教養としてのデータサイエンス（講談社 データサイエンス入門シリーズ）](https://www.kspub.co.jp/book/detail/5238097.html)
# *   [3] [Pythonで学ぶアルゴリズムとデータ構造（講談社 データサイエンス入門シリーズ）](https://www.kspub.co.jp/book/detail/5178034.html)
# *   [4] [テキスト・画像・音声データ分析（講談社 データサイエンス入門シリーズ）](https://www.kspub.co.jp/book/detail/5188040.html)

# %% [markdown]
# ## 1. 構造化データ，非構造化データ

# %% [markdown]
# ### 1.1 [1] #4,5

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-2_big_data.pdf#page=4"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/2/UTAI-text/JPEG/2-2_data_expression_04.jpg' alt='構造化データ' width='640' border='1'></a>
# </figure>

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-2_big_data.pdf#page=5"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/2/UTAI-text/JPEG/2-2_data_expression_05.jpg' alt='構造化データ' width='640' border='1'></a>
# </figure>

# %% [markdown]
# ### 1.2 [2] sec.1.2.3,

# %% [markdown]
# ## 2. データの表現方法(1)　数値

# %% [markdown]
# ### 2.1 [1] #6--

# %% [markdown]
# ### 2.2 [3] sec.1.1, sec.2.1,

# %% [markdown]
# ## 3. データ構造（配列，木構造，グラフ）

# %% [markdown]
# ### 3.1 [1] #21--

# %% [markdown]
# ### 3.2 [3] sec.2.2, sec.5.1, sec.5.2, sec.6.1, sec.6.2

# %% [markdown]
# ## 4. データの表現方法(2)　テキストデータ

# %% [markdown]
# ### 4.1 [1] #8--

# %% [markdown]
# ### 4.2 [4] Part.I, sec.3 テキスト分析/基礎技術

# %% [markdown]
# ## 5. データの表現方法(3)　音声データ

# %% [markdown]
# ### 5.1 [1] #11--

# %% [markdown]
# ### 5.2 [4] PartIII, sec.2 音声データの特徴量解析

# %% [markdown]
# ## 6. データの表現方法(4)　画像データ

# %% [markdown]
# ### 6.1 [1] #17--

# %% [markdown]
# ### 6.2 [4] Part.II, sec.3 二次元画像解析

# %% [markdown]
# ## 1. ICT（情報通信技術）の進展，ビッグデータ
#
# 現在，スマートスピーカーや自動運転など，驚異的に発達した人工知能（Artifical Intelligence, AI）を活用した技術が私達の日常生活まで深く入りこんできている．
# AIの導入は産業界においても積極的に進められており，小売業をはじめとして製造業にいたるまで，ありとあらゆる産業分野でビジネスの形態が変化しつつある．
# AIが適切に動作するためには，膨大な量のデータ，いわゆる「ビッグデータ」の存在が欠かせない [2]．
#
# ここでは，AIにより引き起こされる社会や日常の大きな変化を認識する．
# またAIが活用されている領域や現場，代表的な技術などを紹介する．
# あわせて，AIに必須のデータがどのような形で収集され，いかに整理され分析されるのか，データ処理の大まかな流れについて学ぶ．

# %% [markdown]
# ### 1.1 ビッグデータとは / データ量の増大 / ビッグデータ利活用のための課題 [1]

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=4"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_04.jpg' alt='ビッグデータとは' width='640' border='1'></a>
# </figure>
#
# *   [Big data: The next frontier for innovation, competition, and productivity | McKinsey](https://www.mckinsey.com/business-functions/mckinsey-digital/our-insights/big-data-the-next-frontier-for-innovation)

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=5"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_05.jpg' alt='データ量の増大' width='640' border='1'></a>
# </figure>
#
# *   [DATA NEVER SLEEPS 7.0: How much data is generated every minute? | MONO](https://web-assets.domo.com/blog/wp-content/uploads/2019/07/data-never-sleeps-7-896kb.jpg)

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=6"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_06.jpg' alt='ビッグデータ利活用のための課題' width='640' border='1'></a>
# </figure>
#
# ※注記：スライド6説明中「2-6」の部分は，本コンテンツでは sec.6 と読み替えてください．

# %% [markdown]
# ### 1.2 ビッグデータとデータエンジニアリングを実現可能とした背景：ICT（情報通信技術）の進展 [1]

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=7"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_07.jpg' alt='ICT（情報通信技術）の進展' width='640' border='1'></a>
# </figure>

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=8"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_08.jpg' alt='ICT（情報通信技術）の進展' width='640' border='1'></a>
# </figure>
#
# *    [総務省 | 令和2年版情報通信白書 ブロードバンド契約数の推移](https://www.soumu.go.jp/johotsusintokei/whitepaper/ja/r02/html/nd252210.html)

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=9"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_09.jpg' alt='ICT（情報通信技術）の進展' width='640' border='1'></a>
# </figure>
#
# *    [OCN | 日本のインターネット人口は20年で1億人を突破 (2016年)](https://www.ocn.ne.jp/ocn20th/history/column1/)

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=10"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_10.jpg' alt='ICT（情報通信技術）の進展' width='640' border='1'></a>
# </figure>
#
# *    [総務省 | 令和2年版情報通信統計 情報通信機器の世帯保有率の推移](https://www.soumu.go.jp/johotsusintokei/whitepaper/ja/r01/image/n3201010.png)

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=11"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_11.jpg' alt='ICT（情報通信技術）の進展' width='640' border='1'></a>
# </figure>
#
# *    [総務省 | 我が国のインターネットにおけるトラヒックの集計結果 (2021年11月)](https://www.soumu.go.jp/main_content/000731585.pdf)

# %% [markdown]
# <figure>
# <a href="http://www.mi.u-tokyo.ac.jp/pdf/2-1_big_data.pdf#page=12"><img src='https://raw.githubusercontent.com/MDASH-shinshu/MDASH-T-DE/main/1/UTAI-text/JPEG/2-1_big_data_12.jpg' alt='ICT（情報通信技術）の進展' width='640' border='1'></a>
# </figure>
#
# *    [総務省 | 令和3年版情報通信統計 移動体トラヒックの推移](https://www.soumu.go.jp/johotsusintokei/field/data/gt010602.pdf)
#
# ※注記：スライド7説明中「2-3」の部分は，本コンテンツでは sec.3 と読み替えてください．

# %% [markdown]
# # memo
